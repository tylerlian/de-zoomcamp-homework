# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
df = pd.read_csv('green_tripdata_2019-09.csv')
# Out:
# /tmp/ipykernel_4726/3716745654.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('green_tripdata_2019-09.csv')

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime, format='%Y-%m-%d')
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime, format='%Y-%m-%d')

# %%
df.to_sql(name='green_trip_data', con=engine, if_exists='append')
# Out:
# 63

# %%
df[df.lpep_pickup_datetime == '2019-09-18' && df.lpep_dropoff_datetime == '2019-09-18']
# Out:
#   Cell In[35], line 1
#     df[df.lpep_pickup_datetime == '2019-09-18' && df.lpep_dropoff_datetime == '2019-09-18']
#                                                 ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-09-01 00:10:53   2019-09-01 00:23:46
# 1            2.0  2019-09-01 00:31:22   2019-09-01 00:44:37
# 2            2.0  2019-09-01 00:50:24   2019-09-01 01:03:20
# 3            2.0  2019-09-01 00:27:06   2019-09-01 00:33:22
# 4            2.0  2019-09-01 00:43:23   2019-09-01 00:59:54
# ...          ...                  ...                   ...
# 449058       NaN  2019-09-30 23:13:00   2019-09-30 23:41:00
# 449059       NaN  2019-09-30 23:26:00   2019-09-30 23:46:00
# 449060       NaN  2019-09-30 23:15:00   2019-09-30 23:43:00
# 449061       NaN  2019-09-30 23:19:00   2019-10-01 00:06:00
# 449062       NaN  2019-09-30 23:35:00   2019-09-30 23:58:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0            65           189
# 1                       N         1.0            97           225
# ...

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
zone = pd.read_csv('taxi+_zone_lookup.csv')

# %%
zone.to_sql(name='zone_data', con=engine, if_exists='replace')
# Out:
# 265
